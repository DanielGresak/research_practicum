# %%
import pandas as pd

# %%
df = pd.read_excel('WeatherDataFor2018.xlsx')

# %%
df_Info=df.head(21)

# %%
df_Info
# Out:
#                                Station Name: CASEMENT         Unnamed: 1  \
# 0                               Station Height: 91 M                 NaN
# 1                                   Latitude:53.306    Longitude: -6.439
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                       date:  -  Date and Time (utc)                NaN
# 5             rain:  -  Precipitation Amount (mm)\t                  NaN
# 6                     temp:  -  Air Temperature (C)\t                NaN
# 7                  wetb:  -  Wet Bulb Temperature (C)                NaN
# 8    dewpt: -  Dew Point Temperature (C)                             NaN
# 9                     rhum:  -  Relative Humidity (%)                NaN
# 10                 vappr: -  Vapour Pressure (hPa)\t                 NaN
# 11            msl:   -  Mean Sea Level Pressure (hPa)                NaN
# ...

# %%
df_Info = df_Info[['Station Name: CASEMENT', 'Unnamed: 1']]

# %%
df_Info
# Out:
#                                Station Name: CASEMENT         Unnamed: 1
# 0                               Station Height: 91 M                 NaN
# 1                                   Latitude:53.306    Longitude: -6.439
# 2                                                 NaN                NaN
# 3                                                 NaN                NaN
# 4                       date:  -  Date and Time (utc)                NaN
# 5             rain:  -  Precipitation Amount (mm)\t                  NaN
# 6                     temp:  -  Air Temperature (C)\t                NaN
# 7                  wetb:  -  Wet Bulb Temperature (C)                NaN
# 8    dewpt: -  Dew Point Temperature (C)                             NaN
# 9                     rhum:  -  Relative Humidity (%)                NaN
# 10                 vappr: -  Vapour Pressure (hPa)\t                 NaN
# 11            msl:   -  Mean Sea Level Pressure (hPa)                NaN
# ...

# %%
df_content = df.iloc[22:]

# %%
df_content.index -= 22

# %%
df_content.columns = df_content.iloc[0]
df_content = df_content[1:]

# %%
df_content.index -= 1

# %%
df_content.head(10)
# Out:
# 0                 date ind rain ind temp ind wetb dewpt vappr rhum  ... ind  \
# 0  2018-01-01 00:00:00   0  0.1   0    4   0  3.2     2     7   87  ...   2
# 1  2018-01-01 01:00:00   2    0   0  4.3   0  3.5   2.4   7.2   87  ...   2
# 2  2018-01-01 02:00:00   2    0   0  4.3   0  3.5   2.2   7.2   87  ...   2
# 3  2018-01-01 03:00:00   0    0   0  4.7   0  3.9   2.6   7.4   87  ...   2
# 4  2018-01-01 04:00:00   0    0   0  4.8   0  3.9   2.6   7.4   86  ...   2
# 5  2018-01-01 05:00:00   0    0   0  4.7   0  3.7   2.2   7.2   84  ...   2
# 6  2018-01-01 06:00:00   0    0   0  4.4   0  3.5   2.2   7.1   85  ...   2
# 7  2018-01-01 07:00:00   0    0   0  4.1   0  3.3   2.2   7.1   87  ...   2
# 8  2018-01-01 08:00:00   0    0   0  3.9   0  3.2   2.2   7.1   88  ...   2
# 9  2018-01-01 09:00:00   0    0   0  4.3   0  3.5   2.3   7.2   87  ...   2
#
# 0 wdsp ind wddir  ww   w  sun  vis clht clamt
# 0   20   2   220  60  61  NaN  NaN  NaN   NaN
# ...
